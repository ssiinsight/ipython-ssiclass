# %% [markdown]
# # 这是数据新闻班的软件课程

# %% [markdown]
# 数据新闻是大数据时代的产物，大数据助力了数据新闻的发展

# %%
import plotly
import plotly.plotly as py
from plotly.graph_objs import *
py.sign_in("ShenHenry", "9jmux49p27")
import numpy as np

x = np.random.randn(500)
y = np.random.randn(500)+1

data = Data([
    Histogram2d(
        x=x,
        y=y
    )
])
plot_url = py.iplot(data, filename='2d-histogram')

# %% [markdown]
# ### 下面我们把图画出来

# %%
plot_url
